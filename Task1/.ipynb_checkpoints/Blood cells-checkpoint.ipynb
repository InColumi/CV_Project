# %% [markdown]
# # Выделить и посчитать клетки крови

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math

from ipywidgets import interact

# %% [markdown]
# # Функция вывода изображения

# %%
def showImage(images, size = 15, colorMap = 'gray'):
    countImages = len(images)
    #size *= countImages
    pic_box = plt.figure(figsize=(size, size * countImages))
    for i, image in enumerate(images):
        pic_box.add_subplot(countImages, 2, i+1)
        plt.imshow(image)
        plt.set_cmap(colorMap)
        plt.subplots_adjust(wspace=0, hspace=0.1)
        plt.axis('off')
    plt.show()

# %%
image_srs = cv2.imread('1.png')
image_gray = cv2.cvtColor(image_srs,cv2.COLOR_BGR2GRAY)

# %% [markdown]
# # Исходное изображение и изображение в серых тонах

# %%
showImage([image_srs, image_gray])

# %% [markdown]
# # Преобразования Хафа

# %%
image_blured = cv2.GaussianBlur(image_gray, (25,25), 0)
print(type(image_blured), image_blured.shape)
# Out:
# <class 'numpy.ndarray'> (750, 1000)

# %% [raw]
# def transformCircle(a, b, param1, param2, minRadius, maxRadius):
#     circles = cv2.HoughCircles(image_blured,
#                                cv2.HOUGH_GRADIENT,
#                                a,
#                                b,
#                                param1=param1,
#                                param2=param1 // 2,
#                                minRadius=minRadius,
#                                maxRadius=maxRadius)
#     circles = np.uint16(np.around(circles))
#     cimg = cv2.cvtColor(image_gray,cv2.COLOR_GRAY2BGR)
#     for i in circles[0,:]:
#         # draw the outer circle
#         cv2.circle(cimg, (i[0], i[1]), i[2], (0, 255, 0),2)
#         # draw the center of the circle
#         cv2.circle(cimg, (i[0], i[1]), 2, (255, 0, 0), 3)
#     print("Найдено клеток: ", circles[0].shape[0])
#     showImage([cimg], size=25)
# interact(transformCircle, a=(1, 10), b=(1, 90), param1=(1, 100), param2=(1, 40), minRadius=(1, 46), maxRadius=(1, 94))

# %%
circles = cv2.HoughCircles(image_blured, cv2.HOUGH_GRADIENT, 1, 50, param1=42,param2=21, minRadius=28, maxRadius=58)

# %%
circles = np.uint16(np.around(circles))
cimg = cv2.cvtColor(image_gray,cv2.COLOR_GRAY2BGR)
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(cimg, (i[0], i[1]), i[2], (0, 255, 0),2)
    # draw the center of the circle
    cv2.circle(cimg, (i[0], i[1]), 2, (255, 0, 0), 3)
print("Найдено клеток: ", circles[0].shape[0])
showImage([cimg], size=40)
# Out:
# Найдено клеток:  43
